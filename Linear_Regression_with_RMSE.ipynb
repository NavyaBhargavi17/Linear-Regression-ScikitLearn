# %%
# Step 1: Import necessary libraries
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error as MSE
from sklearn.model_selection import train_test_split

# %%
# Step 2: Prepare the dataset
# X and y values (features and target)
X = [1, 2, 3, 4, 5]
y = [2, 4, 5, 4, 5]

# Convert lists to numpy arrays and reshape for sklearn
X = np.array(X).reshape(-1, 1)  # 2D array
y = np.array(y).reshape(-1, 1)  # 2D array

# %%
# Step 3: Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Step 4: Create and train the linear regression model
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Step 5: Make predictions on the test set
y_pred = reg.predict(X_test)
print("Predicted values:", y_pred)
# Out:
# Predicted values: [[3.14285714]
#  [5.5       ]]

# %%
# Step 6: Evaluate the model using Root Mean Squared Error (RMSE)
rmse = MSE(y_test, y_pred) ** 0.5
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
# Out:
# Root Mean Squared Error (RMSE): 0.70

# %%
# Step 7: Print model coefficients
print("Slope (Coefficient):", reg.coef_[0][0])
print("Intercept:", reg.intercept_[0])
# Out:
# Slope (Coefficient): 0.7857142857142857
# Intercept: 1.5714285714285716

# %%
# Step 8: Visualize the regression line
import matplotlib.pyplot as plt

# Plot training data
plt.scatter(X, y, color='blue', label='Data Points')

# Plot regression line
y_line = reg.predict(X)
plt.plot(X, y_line, color='red', linewidth=2, label='Regression Line')

plt.xlabel("X values")
plt.ylabel("y values")
plt.title("Linear Regression using Scikit-learn")
plt.legend()
plt.show()
